# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
# point
# laitime = [0.187,1.07,42.471]
# laiitem = [79,17,44]

# ndvitime = [0.259,2.64,49.975]
# ndviitem = [103,18,56]

# evitime = [0.32,0.95,35.272]
# eviitem = [58,20,39]

# 108

laitime = [67.7,110.5,120]#154/156
laiitem = [131,19,60]

ndvitime = [12.9,51.2,120]#91/156
ndviitem = [94,24,65]

evitime = [22,150.4,120]#156/156
eviitem = [98,24,65]

# 10884



labels = ['Python', 'Excel','GEE']
 
plt.rcParams['axes.labelsize'] = 15 # xy轴label的size
plt.rcParams['xtick.labelsize'] = 15  # x轴ticks的size
plt.rcParams['ytick.labelsize'] = 15  # y轴ticks的size
 
# 设置柱形的间隔
width = 0.35  # 柱形的宽度
x1_list = []
x2_list = []
for i in range(3):
    x1_list.append(i)
    x2_list.append(i+width)
print('x1_list',x1_list)
print('x2_list',x2_list)


# 创建图层
fig = plt.figure(figsize=(8,10),dpi=300)
ax1 = fig.add_subplot(3,1,1)########################
ax1.set_ylabel('Time')
# ax1.set_ylim(0, 50)
b1=plt.bar(x1_list,laitime, width=width, label="Time",color='mediumspringgreen', align='edge',tick_label=labels)

ax2 = ax1.twinx()
# ax2.set_ylim(0, 100)
ax2.set_ylabel('Item')
b2 = plt.bar(x2_list,laiitem, width=width, label="Item",color='cornflowerblue', align='edge',tick_label=labels)
plt.legend(handles=[b1,b2],loc="upper right",ncol=1)

# plt.text(0,88,'LAI',fontsize=20)
plt.text(0,0,'(LAI)',fontsize=14)

ax3 = fig.add_subplot(3,1,2)########################
ax3.set_ylabel('Time')
# ax3.set_ylim(0, 60)
b1=plt.bar(x1_list,ndvitime, width=width, label="Time",color='mediumspringgreen', align='edge',tick_label=labels)

ax4 = ax3.twinx()
# ax4.set_ylim(0, 120)
ax4.set_ylabel('Item')
b2 = plt.bar(x2_list,ndviitem, width=width, label="Item",color='cornflowerblue', align='edge',tick_label=labels)

plt.legend(handles=[b1,b2],loc="upper right",ncol=1)
# plt.text(0,105,'NDVI',fontsize=20)
plt.text(0,0,'(NDVI)',fontsize=14)

ax3 = fig.add_subplot(3,1,3)########################
ax3.set_ylabel('Time')
# ax3.set_ylim(0, 45)
b1=plt.bar(x1_list,evitime, width=width, label="Time",color='mediumspringgreen', align='edge',tick_label=labels)

ax4 = ax3.twinx()
# ax4.set_ylim(0, 70)
ax4.set_ylabel('Item')
b2 = plt.bar(x2_list,eviitem, width=width, label="Item",color='cornflowerblue', align='edge',tick_label=labels)

plt.legend(handles=[b1,b2],loc="upper right",ncol=1)
# plt.text(0,60,'EVI',fontsize=20)
plt.text(0,0,'(EVI)',fontsize=14)
# plt.show()
plt.savefig('D:/Desktop/mypaper/point/all-time-item-108.jpg',bbox_inches='tight',pad_inches=0.1)
# Out:
# x1_list [0, 1, 2]
# x2_list [0.35, 1.35, 2.35]
