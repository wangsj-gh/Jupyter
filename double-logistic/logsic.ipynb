# %%
import numpy as np
import math
import matplotlib.pyplot as plt
x = np.arange(-10, 10, 0.1)
y=1 / (1 + np.exp(-x))
y1=1 / (1 + np.exp(x)) 
probability_density=np.exp(-x) / (1 + np.exp(-x))**2
y3=1 / (1 + np.exp(-x*3+10))

plt.plot(x, y, label="sigmoid")
plt.plot(x, y3, label="any")

plt.axvline(10/3,label="inflection")
plt.axvline(3/4,label="a/4")
# plt.plot(x, y1, label="sigmoid1")
# plt.plot(x, y2, label="probability_density")
plt.xlabel("x")
plt.ylabel("y")
plt.ylim(0, 1)
plt.legend()
plt.show()

# %%
np.arange(1,365,4)
# Out:
# array([  1,   5,   9,  13,  17,  21,  25,  29,  33,  37,  41,  45,  49,
#         53,  57,  61,  65,  69,  73,  77,  81,  85,  89,  93,  97, 101,
#        105, 109, 113, 117, 121, 125, 129, 133, 137, 141, 145, 149, 153,
#        157, 161, 165, 169, 173, 177, 181, 185, 189, 193, 197, 201, 205,
#        209, 213, 217, 221, 225, 229, 233, 237, 241, 245, 249, 253, 257,
#        261, 265, 269, 273, 277, 281, 285, 289, 293, 297, 301, 305, 309,
#        313, 317, 321, 325, 329, 333, 337, 341, 345, 349, 353, 357, 361])
